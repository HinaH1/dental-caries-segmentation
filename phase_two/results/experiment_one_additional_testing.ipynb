# %% [markdown]
# <a href="https://colab.research.google.com/github/HinaH1/dental-caries-detection-segmentation/blob/main/phase_two/results/experiment_one_additional_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Connect to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# check the structure of the dataset

# %%
import os

# Replace with your actual path
dataset_path = "/content/drive/MyDrive/Copy of DETECTION"

for root, dirs, files in os.walk(dataset_path):
    level = root.replace(dataset_path, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    if level < 2:
        subindent = ' ' * 2 * (level + 1)
        for file in files[:5]:
            print(f'{subindent}{file}')
# Out:
# Copy of DETECTION/
#   DETECTION/
#     labels/
#     images/

# %% [markdown]
# check for yaml and train/test split

# %%
import os

dataset_path = "/content/drive/MyDrive/Copy of DETECTION/DETECTION"

# Check what is at this level
print("Contents of DETECTION/DETECTION:")
for file in os.listdir(dataset_path):
    print(file)

# Check images subfolder
images_path = os.path.join(dataset_path, "images")
print("\nImages folder contains:")
for item in os.listdir(images_path):
    print(item)

# Check labels subfolder
labels_path = os.path.join(dataset_path, "labels")
print("\nLabels folder contains:")
for item in os.listdir(labels_path):
    print(item)
# Out:
# Streaming output truncated to the last 5000 lines.
# test_crawling_365.jpg
# test_crawling_279.jpg
# test_crawling_52.jpg
# test_crawling_391.jpg
# test_crawling_315.jpg
# test_crawling_389.jpg
# test_crawling_355.jpg
# test_crawling_361.jpg
# test_crawling_68.jpg
# test_crawling_77.jpg
# test_crawling_72.jpg
# test_crawling_219.jpg
# test_crawling_188.jpg
# test_crawling_79.jpg
# test_crawling_352.jpg
# test_crawling_5.jpg
# test_crawling_308.jpg
# test_crawling_385.jpg
# test_crawling_42.jpg
# test_crawling_144.jpg
# test_crawling_116.jpg
# test_crawling_369.jpg
# test_crawling_6.jpg
# test_crawling_241.jpg
# test_crawling_212.jpg
# test_crawling_316.jpg
# test_crawling_275.jpg
# test_crawling_93.jpg
# test_crawling_325.jpg
# test_crawling_53.jpg
# test_crawling_166.jpg
# test_crawling_174.jpg
# test_crawling_145.jpg
# test_crawling_250.jpg
# test_crawling_368.jpg
# test_crawling_117.jpg
# test_crawling_329.jpg
# test_crawling_162.jpg
# test_crawling_26.jpg
# test_crawling_94.jpg
# ...

# %%
import os
import shutil

base = "/content/drive/MyDrive/Copy of DETECTION/DETECTION"
images_src = os.path.join(base, "images")
labels_src = os.path.join(base, "labels")

# Create new folder structure
for split in ['train', 'val', 'test']:
    os.makedirs(f"{base}/{split}/images", exist_ok=True)
    os.makedirs(f"{base}/{split}/labels", exist_ok=True)

# Move images
for f in os.listdir(images_src):
    if f.startswith('train_') or f.startswith('train2_'):
        shutil.copy(os.path.join(images_src, f), f"{base}/train/images/{f}")
    elif f.startswith('val_'):
        shutil.copy(os.path.join(images_src, f), f"{base}/val/images/{f}")
    elif f.startswith('test_'):
        shutil.copy(os.path.join(images_src, f), f"{base}/test/images/{f}")

# Move labels
for f in os.listdir(labels_src):
    if f.startswith('train_') or f.startswith('train2_'):
        shutil.copy(os.path.join(labels_src, f), f"{base}/train/labels/{f}")
    elif f.startswith('val_'):
        shutil.copy(os.path.join(labels_src, f), f"{base}/val/labels/{f}")
    elif f.startswith('test_'):
        shutil.copy(os.path.join(labels_src, f), f"{base}/test/labels/{f}")

print("Done reorganising files")
# Out:
# Done reorganising files

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.0 MB/s eta 0:00:00
# ...

# %%
model_path = "/content/drive/MyDrive/best_1.pt"

# %%
test_path = "/content/drive/MyDrive/Copy of DETECTION/DETECTION/test/images"

# %%
from ultralytics import YOLO

model = YOLO(model_path)

# %%
results = model.predict(
    source =test_path,
    save=True,
    project = "/content/drive/MyDrive/exp1_results",
    name = "exp1",
    conf = 0.25
)
# Out:
# image 1/358 /content/drive/MyDrive/Copy of DETECTION/DETECTION/test/images/test_crawling_0.jpg: 640x640 1 caries, 7.7ms
# image 2/358 /content/drive/MyDrive/Copy of DETECTION/DETECTION/test/images/test_crawling_10.jpg: 640x640 1 caries, 14.1ms
# image 3/358 /content/drive/MyDrive/Copy of DETECTION/DETECTION/test/images/test_crawling_100.jpg: 640x640 1 caries, 8.5ms
# image 4/358 /content/drive/MyDrive/Copy of DETECTION/DETECTION/test/images/test_crawling_101.jpg: 640x640 1 caries, 22.1ms
# image 5/358 /content/drive/MyDrive/Copy of DETECTION/DETECTION/test/images/test_crawling_102.jpg: 640x640 2 cariess, 7.9ms
# image 6/358 /content/drive/MyDrive/Copy of DETECTION/DETECTION/test/images/test_crawling_103.jpg: 640x640 2 cariess, 7.5ms
# image 7/358 /content/drive/MyDrive/Copy of DETECTION/DETECTION/test/images/test_crawling_104.jpg: 640x640 1 caries, 7.3ms
# image 8/358 /content/drive/MyDrive/Copy of DETECTION/DETECTION/test/images/test_crawling_105.jpg: 640x640 1 caries, 7.2ms
# ...
